# %%
import pandas as pd

# %%
#pandas stands for panel data, if offers data structure and manipulation of data

# %%
#method 1 of import the data from .csv file (below we use stats but any name can be used)
#if saved in another folder just need to specify the full path to the file
stats = pd.read_csv("sample.csv")

# %%
stats
# Out:
#                               City                   City ID Country  \
# 0                         Abingdon                   1006457      GB
# 1                            Alloa                   1007295      GB
# 2                         Amersham                   1006474      GB
# 3                            Annan                   1007297      GB
# 4                          Baldock                   1006493      GB
# 5                         Barnsley                   1006496      GB
# 6                      Berkhamsted                   1006512      GB
# 7                    Billingshurst                   1006520      GB
# 8                        Birchwood                   1006522      GB
# 9                       Birmingham                   1006524      GB
# 10              Bishop s Stortford                   1006528      GB
# 11                       Blackburn                   1006530      GB
# 12                       Blackpool                   1006532      GB
# ...

# %%
len(stats)
# Out:
# 853

# %%
stats.columns
# Out:
# Index(['City', 'City ID', 'Country', 'Advertiser Currency', 'Impressions',
#        'Clicks', 'Revenue (Adv Currency)'],
#       dtype='object')

# %%
#this calculates the length of the columns
len(stats.columns)
# Out:
# 7

# %%
#below module provides a summary of the dataset, similar to R's summary
stats.describe()
# Out:
# /Applications/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#          Impressions      Clicks  Revenue (Adv Currency)
# count     845.000000  845.000000              845.000000
# mean      652.804734    1.131361                1.715635
# std      9751.330298   16.856743               25.628801
# min         1.000000    0.000000                0.000554
# 25%              NaN         NaN                     NaN
# 50%              NaN         NaN                     NaN
# 75%              NaN         NaN                     NaN
# max    275810.000000  478.000000              724.855704

# %%
#below given object oriented programming the syntax goes like stats.xxx()

# %%
import os

# %%
print(os.getcwd())
# Out:
# /Users/mac/Documents/Python/Dataframe - import - exploration

# %% [markdown]
# ---

# %%
#there is no brackets
stats.columns
# Out:
# Index(['City', 'City ID', 'Country', 'Advertiser Currency', 'Impressions',
#        'Clicks', 'Revenue (Adv Currency)'],
#       dtype='object')

# %%
#number of columgs 
len(stats.columns)
# Out:
# 7

# %%
#top rows, defaults is 5 rows
stats.head()
# Out:
#        City  City ID Country Advertiser Currency  Impressions  Clicks  \
# 0  Abingdon  1006457      GB                 GBP        174.0     1.0
# 1     Alloa  1007295      GB                 GBP         89.0     0.0
# 2  Amersham  1006474      GB                 GBP         45.0     0.0
# 3     Annan  1007297      GB                 GBP         58.0     0.0
# 4   Baldock  1006493      GB                 GBP         93.0     0.0
#
#    Revenue (Adv Currency)
# 0                0.468812
# 1                0.252819
# 2                0.126163
# 3                0.144051
# 4                0.264777

# %%
#by passing 10 in the brackets which will be 10 rows
stats.head(10)
# Out:
#             City  City ID Country Advertiser Currency  Impressions  Clicks  \
# 0       Abingdon  1006457      GB                 GBP        174.0     1.0
# 1          Alloa  1007295      GB                 GBP         89.0     0.0
# 2       Amersham  1006474      GB                 GBP         45.0     0.0
# 3          Annan  1007297      GB                 GBP         58.0     0.0
# 4        Baldock  1006493      GB                 GBP         93.0     0.0
# 5       Barnsley  1006496      GB                 GBP        682.0     1.0
# 6    Berkhamsted  1006512      GB                 GBP         75.0     0.0
# 7  Billingshurst  1006520      GB                 GBP         38.0     0.0
# 8      Birchwood  1006522      GB                 GBP         49.0     0.0
# 9     Birmingham  1006524      GB                 GBP       5049.0     4.0
#
#    Revenue (Adv Currency)
# 0                0.468812
# 1                0.252819
# 2                0.126163
# 3                0.144051
# ...

# %%
#bottom rows
stats.tail(10)
# Out:
#                               City                   City ID Country  \
# 843                           Yarm                   1007263      GB
# 844                            NaN                       NaN     NaN
# 845                   Report Time:      2017/01/08 13:29 GMT     NaN
# 846                    Date Range:  2016/12/09 to 2017/01/07     NaN
# 847                      Group By:                      City     NaN
# 848                      Group By:                   City ID     NaN
# 849                      Group By:                   Country     NaN
# 850                      Group By:       Advertiser Currency     NaN
# 851  Filter by Insertion Order ID:                   2806249     NaN
# 852          Filter by Partner ID:                       151     NaN
#
#     Advertiser Currency  Impressions  Clicks  Revenue (Adv Currency)
# 843                 GBP          5.0     0.0                0.017310
# 844                 NaN     275810.0   478.0              724.855704
# ...

# %%
#infomation on the columns heads
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 853 entries, 0 to 852
# Data columns (total 7 columns):
# City                      852 non-null object
# City ID                   852 non-null object
# Country                   844 non-null object
# Advertiser Currency       844 non-null object
# Impressions               845 non-null float64
# Clicks                    845 non-null float64
# Revenue (Adv Currency)    845 non-null float64
# dtypes: float64(3), object(4)
# memory usage: 46.7+ KB

# %%
#transpose function is as below
stats.describe().transpose()
# Out:
# /Applications/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                         count        mean          std       min  25%  50%  \
# Impressions             845.0  652.804734  9751.330298  1.000000  NaN  NaN
# Clicks                  845.0    1.131361    16.856743  0.000000  NaN  NaN
# Revenue (Adv Currency)  845.0    1.715635    25.628801  0.000554  NaN  NaN
#
#                         75%            max
# Impressions             NaN  275810.000000
# Clicks                  NaN     478.000000
# Revenue (Adv Currency)  NaN     724.855704
